# %% [markdown]
# <h1 style="font-size:300%">HOUSE PRICE PREDICTOR</h1>
#
# This notebook is a starting point for a regression model that predicts house prices based on features of those houses. It uses the Boston House price dataset which is included in this repo as a csv file and represents prices of houses in the city of Boston in the 1970s. The data for this example is included in the git repo, so you can just clone this repo and run the notebook.
#
# Bas S.H.T. Michielsen, 2025

# %% [markdown]
# ![banner](https://raw.githubusercontent.com/bshtmichielsen/house_price_predictor/refs/heads/main/BANNER.jpg)
#
# *Image by Stable Diffusion: a robot selling houses in Boston*

# %%
import csv, pandas, platform, os, seaborn, torch
import lightning as L
import torch.utils.data as D
import torchmetrics as M

data_path = "BostonHousing.csv"
torch.manual_seed(0)

print("Versions: python", platform.python_version(), "| torch", torch.__version__, "| lightning", L.__version__)
# Out:
# Versions: python 3.12.5 | torch 2.10.0 | lightning 2.6.1

# %% [markdown]
# # Create a Dataset
#
# The first thing to do is create a torch Dataset object from the provided csv file. Here we use pandas to load the csv file into a DataFrame and then that DataFrame is used to put the data in a TensorDataset. A TensorDataset is a structure that contains a tensor of values as features and a tensor of values as target. Of our data the last column is the target and all the other columns are the features.

# %%
class TabularDataset(D.TensorDataset):
    """TabularDataSet loads data from a pandas DataFrame assuming the last column is the target and all other columns are features that can be converted to float."""
    def __init__(self, dataframe: pandas.DataFrame):
        rows = dataframe.values.astype(float)
        data = torch.tensor(rows, dtype=torch.float32)
        super().__init__(data[:, :-1], data[:, -1])
    
    def num_features(self) -> int:
        return self[0][0].size()[0]

df = pandas.read_csv(data_path)
dataset = TabularDataset(df)
print("Created a TabularDataset with", dataset.num_features(), "features.")
# Out:
# Created a TabularDataset with 13 features.

# %% [markdown]
# # Sample the data
#
# We can now use the created DataFrame to sample the data. The last column, `medv` is the target and represents the price of the house in $1000. All other columns are used as features to predict `medv` with.

# %%
df.sample(5)
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 59   0.10328  25.0   5.13     0  0.453  5.927  47.2  6.9320    8  284
# 19   0.72580   0.0   8.14     0  0.538  5.727  69.5  3.7965    4  307
# 89   0.05302   0.0   3.41     0  0.489  7.079  63.1  3.4145    2  270
# 307  0.04932  33.0   2.18     0  0.472  6.849  70.3  3.1827    7  222
# 297  0.14103   0.0  13.92     0  0.437  5.790  58.0  6.3200    4  289
#
#      ptratio       b  lstat  medv
# 59      19.7  396.90   9.22  19.6
# 19      21.0  390.95  11.28  18.2
# 89      17.8  396.06   5.70  28.7
# 307     18.4  396.90   7.53  28.2
# 297     16.0  396.90  15.84  20.3

# %% [markdown]
# # Splitting the Dataset
# To train a model, different dataset are needed, first there should be data for training purposes. However, to judge how well the model is fitted we also need data for validation and later for testing purposes. It is a common approach to split the dataset in three parts named `train`, `val` and `test` often in way that a resonably sized validation set and test set are created and the remaining data becoming the train set. For PyTorch Lightning, these three sets are then put together in something called a DataModule.
#
# Note that you can increase `batch_size` or `num_workers` to speed up the process if you find that running this notebook is slow on your computer. However, doing so requires more CPU cores and/or more RAM so at some point you may reach a limit and things may break. The provided values of `batch_size=32` and `num_workers=0` is a safe default that is unlikely to produce errors.

# %%
train, val, test = D.random_split(dataset, [.6, .3, .1])
datamodule = L.LightningDataModule.from_datasets(train, val, test, batch_size=32, num_workers=0)
print("Created a DataModule with:", len(datamodule.train_dataloader().dataset), "training items,", len(datamodule.val_dataloader().dataset), "validation items and", len(datamodule.test_dataloader().dataset), "test items.")
# Out:
# Created a DataModule with: 304 training items, 152 validation items and 50 test items.

# %% [markdown]
# # Defining the Model
# Of course there are many ways to define the model that is going to be trained. This example, though perhaps not the best model in the world, is rather simple and serves as an easy way of getting started with PyTorch Lightning. Here we create a simple feedforward neural network. The model consists of two layers defined in a sequential manner. First, we have a linear layer that takes in the features and transforms them into 64 nodes. This is followed by a ReLU (Rectified Linear Unit) activation function, which introduces non-linearity to the model, allowing it to learn more complex patterns. Finally, the output layer reduces the 64 nodes down to a single output, making this model suitable for regression tasks where we want to predict a single, however, continuous variable.

# %%
from torch import nn

class RegressionModel(L.LightningModule):
    def __init__(self, num_features):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(num_features, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )
        self.criterion = nn.MSELoss()
        self.r2 = M.R2Score()

    def forward(self, x):
        return self.model(x).view(-1)

    def training_step(self, batch):
        x, truth = batch
        out = self(x)
        return self.criterion(out, truth)
    
    def validation_step(self, batch):
        x, truth = batch
        out = self(x)
        loss = self.criterion(out, truth)
        self.log("val_loss", loss)

    def test_step(self, batch):
        x, y = batch
        out = self(x)
        self.log("test_r2", self.r2(out, y), on_step=False, on_epoch=True)

    def predict_step(self, batch):
        x, y = batch
        return self(x)

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=0.001)

model = RegressionModel(num_features=dataset.num_features())

# %% [markdown]
# # Training
# Here we use a PyTorch Lightning Trainer to fit the model using the DataModule that we defined earlier. Internally it will iterate epochs, meaning that it will go through all train data to learn about relationships between the features and the target and then run a validation to gauge its performance which is measured in validation loss, meaning the difference between the true values and the model's predicted values. Here the assumption is that if the validation loss does no longer go down, the model is fitted as best as possible and continue training makes no improvements. We define an EarlyStopping for this that monitors when `val_loss` reaches its minimum. If so, it stops training.

# %%
from lightning.pytorch.loggers import CSVLogger
from lightning.pytorch.callbacks import EarlyStopping

logger = CSVLogger(save_dir=".")
stop = EarlyStopping(monitor="val_loss", mode="min")
trainer = L.Trainer(logger=logger, max_epochs=-1, callbacks=[stop], log_every_n_steps=10)
trainer.fit(model, datamodule=datamodule)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
#
#   | Name      | Type       | Params | Mode  | FLOPs
# ---------------------------------------------------------
# 0 | model     | Sequential | 961    | train | 0
# 1 | criterion | MSELoss    | 0      | train | 0
# 2 | r2        | R2Score    | 0      | train | 0
# ---------------------------------------------------------
# 961       Trainable params
# 0         Non-trainable params
# 961       Total params
# 0.004     Total estimated model params size (MB)
# 6         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /Users/rickpeters/Desktop/Fontys Semester3 Projects/wine-categorizer/.venv/lib/python3.12/site-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /Users/rickpeters/Desktop/Fontys Semester3 Projects/wine-categorizer/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=10` in the `DataLoader` to improve performance.
# /Users/rickpeters/Desktop/Fontys Semester3 Projects/wine-categorizer/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# /Users/rickpeters/Desktop/Fontys Semester3 Projects/wine-categorizer/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=10` in the `DataLoader` to improve performance.
# Epoch 0: 100%|██████████| 10/10 [00:00<00:00, 320.50it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 465.31it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 472.68it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 517.50it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 546.52it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 562.48it/s]
# Epoch 1: 100%|██████████| 10/10 [00:00<00:00, 338.40it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 495.02it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 500.99it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 525.95it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 555.41it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 569.62it/s]
# Epoch 2: 100%|██████████| 10/10 [00:00<00:00, 386.70it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 489.19it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 511.63it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 542.98it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 567.93it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 577.70it/s]
# Epoch 3: 100%|██████████| 10/10 [00:00<00:00, 445.27it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 512.06it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 500.10it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 544.57it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 567.14it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 589.68it/s]
# Epoch 4: 100%|██████████| 10/10 [00:00<00:00, 471.55it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 522.46it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 538.08it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 575.27it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 601.51it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 621.82it/s]
# Epoch 5: 100%|██████████| 10/10 [00:00<00:00, 372.30it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 417.22it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 439.56it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 483.25it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 507.05it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 527.11it/s]
# Epoch 6: 100%|██████████| 10/10 [00:00<00:00, 386.89it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 538.77it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 518.26it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 547.13it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 507.11it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 534.07it/s]
# Epoch 7: 100%|██████████| 10/10 [00:00<00:00, 341.34it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 499.02it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 508.00it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 510.65it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 464.20it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 494.61it/s]
# Epoch 8: 100%|██████████| 10/10 [00:00<00:00, 372.43it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 495.78it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 508.12it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 521.72it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 466.73it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 492.12it/s]
# Epoch 9: 100%|██████████| 10/10 [00:00<00:00, 430.91it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 538.28it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 506.50it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 426.81it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 459.20it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 481.88it/s]
# Epoch 10: 100%|██████████| 10/10 [00:00<00:00, 371.02it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 524.68it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 510.63it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 557.85it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 490.75it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 516.54it/s]
# Epoch 11: 100%|██████████| 10/10 [00:00<00:00, 415.84it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 529.92it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 523.70it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 538.49it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 568.26it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 588.92it/s]
# Epoch 12: 100%|██████████| 10/10 [00:00<00:00, 408.55it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 514.39it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 496.54it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 532.27it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 562.65it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 572.93it/s]
# Epoch 13: 100%|██████████| 10/10 [00:00<00:00, 395.37it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 527.72it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 523.01it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 568.28it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 586.51it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 545.38it/s]
# Epoch 14: 100%|██████████| 10/10 [00:00<00:00, 393.27it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 512.88it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 520.84it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 553.44it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 578.70it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 592.30it/s]
# Epoch 15: 100%|██████████| 10/10 [00:00<00:00, 402.13it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 486.58it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 475.03it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 516.07it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 477.78it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 498.89it/s]
# Epoch 16: 100%|██████████| 10/10 [00:00<00:00, 420.95it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 500.45it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 501.38it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 543.19it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 577.29it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 577.36it/s]
# Epoch 17: 100%|██████████| 10/10 [00:00<00:00, 396.01it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 464.69it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 484.02it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 512.10it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 540.97it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 555.61it/s]
# Epoch 18: 100%|██████████| 10/10 [00:00<00:00, 392.64it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 519.23it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 503.28it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 475.96it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 501.01it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 525.48it/s]
# Epoch 19: 100%|██████████| 10/10 [00:00<00:00, 410.85it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 525.21it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 403.80it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 453.65it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 490.62it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 509.22it/s]
# Epoch 20: 100%|██████████| 10/10 [00:00<00:00, 381.52it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 462.95it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 447.92it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 364.30it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 398.80it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 434.44it/s]
# Epoch 21: 100%|██████████| 10/10 [00:00<00:00, 359.53it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 497.31it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 474.07it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 502.43it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 492.32it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 512.99it/s]
# Epoch 22: 100%|██████████| 10/10 [00:00<00:00, 374.35it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 477.55it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 494.82it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 529.38it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 550.89it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 570.39it/s]
# Epoch 23: 100%|██████████| 10/10 [00:00<00:00, 402.27it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 518.90it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 535.91it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 573.28it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 586.84it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 591.58it/s]
# Epoch 24: 100%|██████████| 10/10 [00:00<00:00, 471.10it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 570.89it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 530.69it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 562.54it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 578.88it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 590.40it/s]
# Epoch 25: 100%|██████████| 10/10 [00:00<00:00, 485.37it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 534.78it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 520.58it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 561.49it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 581.23it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 594.04it/s]
# Epoch 26: 100%|██████████| 10/10 [00:00<00:00, 478.79it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 547.13it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 528.12it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 566.90it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 597.82it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 609.39it/s]
# Epoch 27: 100%|██████████| 10/10 [00:00<00:00, 479.02it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 526.33it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 524.94it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 564.66it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 580.39it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 603.06it/s]
# Epoch 28: 100%|██████████| 10/10 [00:00<00:00, 494.76it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 538.84it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 538.80it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 571.74it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 597.01it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 608.28it/s]
# Epoch 29: 100%|██████████| 10/10 [00:00<00:00, 495.29it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 588.18it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 463.38it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 463.60it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 479.77it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 492.37it/s]
# Epoch 30: 100%|██████████| 10/10 [00:00<00:00, 426.69it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 462.34it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 501.26it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 547.15it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 578.70it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 591.65it/s]
# Epoch 31: 100%|██████████| 10/10 [00:00<00:00, 409.60it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 490.68it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 493.97it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 539.69it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 549.39it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 557.55it/s]
# Epoch 32: 100%|██████████| 10/10 [00:00<00:00, 407.43it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 465.78it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 472.57it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 371.98it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 393.08it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 409.20it/s]
# Epoch 33: 100%|██████████| 10/10 [00:00<00:00, 436.47it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 561.49it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 532.78it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 573.07it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 599.98it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 601.04it/s]
# Epoch 34: 100%|██████████| 10/10 [00:00<00:00, 461.54it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 543.23it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 548.88it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 578.05it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 584.73it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 594.18it/s]
# Epoch 35: 100%|██████████| 10/10 [00:00<00:00, 481.88it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 551.01it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 532.47it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 555.88it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 582.66it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 592.78it/s]
# Epoch 36: 100%|██████████| 10/10 [00:00<00:00, 477.37it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 526.86it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 526.89it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 570.45it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 590.91it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 599.67it/s]
# Epoch 37: 100%|██████████| 10/10 [00:00<00:00, 291.55it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 428.08it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 429.92it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 433.40it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 458.26it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 465.03it/s]
# Epoch 38: 100%|██████████| 10/10 [00:00<00:00, 362.78it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 560.29it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 529.28it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 566.26it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 588.94it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 595.75it/s]
# Epoch 39: 100%|██████████| 10/10 [00:00<00:00, 307.78it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 542.60it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 508.77it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 535.81it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 546.74it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 571.68it/s]
# Epoch 40: 100%|██████████| 10/10 [00:00<00:00, 462.91it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 570.58it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 543.23it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 569.39it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 532.14it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 552.13it/s]
# Epoch 41: 100%|██████████| 10/10 [00:00<00:00, 336.38it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 398.74it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 381.82it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 421.76it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 432.30it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 424.06it/s]
# Epoch 42: 100%|██████████| 10/10 [00:00<00:00, 337.38it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 406.19it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 426.88it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 458.78it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 462.85it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 429.55it/s]
# Epoch 43: 100%|██████████| 10/10 [00:00<00:00, 345.27it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 444.03it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 448.64it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 437.71it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 457.08it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 476.82it/s]
# Epoch 44: 100%|██████████| 10/10 [00:00<00:00, 308.36it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 464.02it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 457.77it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 451.32it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 449.43it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 433.39it/s]
# Epoch 45: 100%|██████████| 10/10 [00:00<00:00, 291.97it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 433.25it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 464.67it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 441.43it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 466.09it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 443.94it/s]
# Epoch 46: 100%|██████████| 10/10 [00:00<00:00, 288.47it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 474.31it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 419.62it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 454.60it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 451.00it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 423.73it/s]
# Epoch 47: 100%|██████████| 10/10 [00:00<00:00, 328.94it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 506.13it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 410.68it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 407.83it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 425.67it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 449.93it/s]
# Epoch 48: 100%|██████████| 10/10 [00:00<00:00, 321.53it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 391.22it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 448.71it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 450.16it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 402.85it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 424.80it/s]
# Epoch 49: 100%|██████████| 10/10 [00:00<00:00, 315.90it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 383.25it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 415.36it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 401.60it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 433.73it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 454.45it/s]
# Epoch 50: 100%|██████████| 10/10 [00:00<00:00, 318.42it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 449.89it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 484.05it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 502.35it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 457.57it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 470.68it/s]
# Epoch 51: 100%|██████████| 10/10 [00:00<00:00, 354.82it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 491.14it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 469.69it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 483.23it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 505.81it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 518.83it/s]
# Epoch 52: 100%|██████████| 10/10 [00:00<00:00, 306.60it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 288.27it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 329.75it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 348.52it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 311.38it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 337.50it/s]
# Epoch 53: 100%|██████████| 10/10 [00:00<00:00, 351.18it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 582.06it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 527.55it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 563.04it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 542.00it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 549.76it/s]
# Epoch 54: 100%|██████████| 10/10 [00:00<00:00, 362.25it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 494.26it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 481.33it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 490.75it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 505.57it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 501.15it/s]
# Epoch 55: 100%|██████████| 10/10 [00:00<00:00, 359.70it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 513.38it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 497.52it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 535.83it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 553.50it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 570.33it/s]
# Epoch 56: 100%|██████████| 10/10 [00:00<00:00, 387.49it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 489.93it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 497.75it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 514.32it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 544.57it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 559.54it/s]
# Epoch 57: 100%|██████████| 10/10 [00:00<00:00, 381.69it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 308.54it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 365.48it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 420.88it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 456.31it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 484.92it/s]
# Epoch 58: 100%|██████████| 10/10 [00:00<00:00, 379.85it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Epoch 77: 100%|██████████| 10/10 [00:00<00:00, 440.22it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 567.26it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 560.25it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 589.06it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 608.55it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 609.32it/s]
# Epoch 78: 100%|██████████| 10/10 [00:00<00:00, 440.89it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 551.88it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 564.97it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 581.41it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 603.61it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 611.25it/s]
# Epoch 79: 100%|██████████| 10/10 [00:00<00:00, 454.30it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 488.28it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 504.27it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 541.99it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 568.83it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 585.01it/s]
# Epoch 80: 100%|██████████| 10/10 [00:00<00:00, 436.76it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 556.50it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 506.71it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 545.94it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 568.58it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 585.75it/s]
# Epoch 81: 100%|██████████| 10/10 [00:00<00:00, 428.69it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 564.97it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 555.43it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 595.02it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 617.85it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 627.66it/s]
# Epoch 82: 100%|██████████| 10/10 [00:00<00:00, 434.03it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 538.21it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 506.34it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 547.15it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 566.89it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 585.36it/s]
# Epoch 83: 100%|██████████| 10/10 [00:00<00:00, 425.64it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 605.41it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 573.07it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 590.30it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 618.13it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 622.52it/s]
# Epoch 84: 100%|██████████| 10/10 [00:00<00:00, 417.38it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 480.34it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 513.88it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 529.56it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 545.19it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 511.45it/s]
# Epoch 85: 100%|██████████| 10/10 [00:00<00:00, 380.52it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 546.70it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 541.27it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 584.11it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 592.60it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 599.31it/s]
# Epoch 86: 100%|██████████| 10/10 [00:00<00:00, 376.35it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 461.67it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 454.84it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 469.04it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 483.27it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 498.89it/s]
# Epoch 87: 100%|██████████| 10/10 [00:00<00:00, 296.81it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 436.50it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 456.08it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 450.79it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 464.19it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 465.93it/s]
# Epoch 88: 100%|██████████| 10/10 [00:00<00:00, 281.77it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 461.47it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 402.43it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 410.51it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 407.76it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 417.95it/s]
# Epoch 89: 100%|██████████| 10/10 [00:00<00:00, 321.11it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 438.41it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 449.65it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 448.70it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 475.52it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 491.35it/s]
# Epoch 90: 100%|██████████| 10/10 [00:00<00:00, 272.42it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 407.69it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 413.23it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 455.79it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 479.34it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 479.44it/s]
# Epoch 91: 100%|██████████| 10/10 [00:00<00:00, 353.69it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 408.52it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 333.68it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 358.18it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 391.89it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 404.97it/s]
# Epoch 92: 100%|██████████| 10/10 [00:00<00:00, 284.81it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 380.95it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 393.61it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 407.70it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 427.16it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 440.91it/s]
# Epoch 93: 100%|██████████| 10/10 [00:00<00:00, 254.77it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 246.17it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 298.27it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 345.82it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 375.34it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 358.67it/s]
# Epoch 94: 100%|██████████| 10/10 [00:00<00:00, 254.70it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 388.69it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 344.12it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 368.57it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 394.32it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 413.34it/s]
# Epoch 95: 100%|██████████| 10/10 [00:00<00:00, 283.78it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 211.85it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 191.06it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 236.09it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 274.97it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 277.90it/s]
# Epoch 96: 100%|██████████| 10/10 [00:00<00:00, 256.42it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 420.19it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 369.01it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 389.17it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 412.41it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 414.77it/s]
# Epoch 97: 100%|██████████| 10/10 [00:00<00:00, 320.85it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 457.84it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 467.93it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 466.62it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 450.09it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 460.28it/s]
# Epoch 98: 100%|██████████| 10/10 [00:00<00:00, 287.50it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 433.65it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 387.29it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 354.82it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 359.26it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 368.54it/s]
# Epoch 99: 100%|██████████| 10/10 [00:00<00:00, 298.89it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 392.17it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 386.32it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 384.38it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 408.05it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 411.12it/s]
# Epoch 100: 100%|██████████| 10/10 [00:00<00:00, 362.49it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 501.77it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 485.68it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 522.31it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 547.58it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 559.54it/s]
# Epoch 101: 100%|██████████| 10/10 [00:00<00:00, 364.95it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 480.94it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 440.14it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 484.65it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 515.52it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 526.47it/s]
# Epoch 102: 100%|██████████| 10/10 [00:00<00:00, 411.67it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 558.05it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 516.95it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 549.78it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 571.35it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 579.66it/s]
# Epoch 103: 100%|██████████| 10/10 [00:00<00:00, 361.76it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 509.39it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 512.91it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 557.70it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 589.77it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 590.93it/s]
# Epoch 104: 100%|██████████| 10/10 [00:00<00:00, 423.46it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 483.10it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 368.86it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 353.23it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 375.87it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 398.60it/s]
# Epoch 105: 100%|██████████| 10/10 [00:00<00:00, 367.77it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 485.23it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 392.71it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 441.65it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 469.49it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 488.53it/s]
# Epoch 106: 100%|██████████| 10/10 [00:00<00:00, 375.76it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 395.58it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 413.48it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 443.14it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 452.34it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 476.55it/s]
# Epoch 107: 100%|██████████| 10/10 [00:00<00:00, 374.03it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 499.02it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 498.25it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 519.48it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 528.13it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 540.67it/s]
# Epoch 108: 100%|██████████| 10/10 [00:00<00:00, 402.02it/s, v_num=4]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/5 [00:00<?, ?it/s]
# Validation DataLoader 0:  20%|██        | 1/5 [00:00<00:00, 481.22it/s]
# Validation DataLoader 0:  40%|████      | 2/5 [00:00<00:00, 491.37it/s]
# Validation DataLoader 0:  60%|██████    | 3/5 [00:00<00:00, 535.69it/s]
# Validation DataLoader 0:  80%|████████  | 4/5 [00:00<00:00, 547.93it/s]
# Validation DataLoader 0: 100%|██████████| 5/5 [00:00<00:00, 573.32it/s]
# Epoch 108: 100%|██████████| 10/10 [00:00<00:00, 233.06it/s, v_num=4]

# %% [markdown]
# # Evaluation
# Now that the model finished training, let's evaluate it. First we can plot the logged valiation loss and see that it has reached its minimum.

# %%
metrics = pandas.read_csv(os.path.join(trainer.log_dir, "metrics.csv"))
plot = metrics[["epoch", "val_loss"]].set_index("epoch").plot()

# %% [markdown]
# Given that the `val_loss` has flatlined (it is no longer going down), the early stop callback has stopped the training process.

# %% [markdown]
# Now let's run the model against the test data and get an indication for how well it is performing. A typical metric for regression models is R-squared which is the proportion of the variation in the target that is predictable from the features. In other words, how well can the target be predicted using the features. An R-squared closer to 0.0 is worse and closer to 1.0 is better.

# %%
score = trainer.test(model, datamodule=datamodule)
# Out:
# /Users/rickpeters/Desktop/Fontys Semester3 Projects/wine-categorizer/.venv/lib/python3.12/site-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /Users/rickpeters/Desktop/Fontys Semester3 Projects/wine-categorizer/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=10` in the `DataLoader` to improve performance.
# /Users/rickpeters/Desktop/Fontys Semester3 Projects/wine-categorizer/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# Testing DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 126.09it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#          test_r2            0.6255150437355042
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────

# %% [markdown]
# A regplot shows how well the predictions of the model align with the truth values. Dots on or close ot the line are good predictions whereas if dots are scatterd away from the line it indicates that our model is not doing well. The shaded area represents the expected confidence interval and dots within the shaded area are considered close to the line. Morever, this plot shows that our model does reasonably well for houses priced between 15000 and 30000 but does a bit less good for houses that are more expensive or cheaper, as dots appear farther away from the line in those price ranges.

# %%
dataloader = datamodule.test_dataloader()
output = trainer.predict(model, dataloaders=dataloader)
predictions = torch.cat(output)
results = [[round(truth[1].item(),1), round(prediction.item(),1)] for truth, prediction in zip(dataloader.dataset, predictions)]
df = pandas.DataFrame(results, columns=["truth", "prediction"])
plot = seaborn.regplot(data=df, y="truth", x="prediction")
# Out:
# /Users/rickpeters/Desktop/Fontys Semester3 Projects/wine-categorizer/.venv/lib/python3.12/site-packages/lightning/pytorch/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /Users/rickpeters/Desktop/Fontys Semester3 Projects/wine-categorizer/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'predict_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=10` in the `DataLoader` to improve performance.
# /Users/rickpeters/Desktop/Fontys Semester3 Projects/wine-categorizer/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# Predicting DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 649.12it/s]

# %% [markdown]
# Here we print out all truth values, predicted values and the error (absolute difference between them) for all 50 items in the test data.

# %%
df["error"] = abs(df["truth"] - df["prediction"])
df
# Out:
#     truth  prediction  error
# 0    18.5        16.9    1.6
# 1    27.1        23.6    3.5
# 2    22.6        22.1    0.5
# 3    14.3        18.1    3.8
# 4    25.0        24.2    0.8
# 5    17.2        11.8    5.4
# 6    21.0        21.3    0.3
# 7    18.2        22.2    4.0
# 8    23.1        25.1    2.0
# 9    16.1        17.6    1.5
# 10   24.4        24.6    0.2
# 11   20.8        21.4    0.6
# 12   23.7        23.6    0.1
# 13   29.0        23.3    5.7
# 14   22.8        24.2    1.4
# 15   31.7        25.9    5.8
# 16   37.9        36.7    1.2
# 17   32.2        27.0    5.2
# 18   36.0        31.3    4.7
# 19   15.4        16.3    0.9
# 20   16.1        17.2    1.1
# 21   13.8         7.6    6.2
# 22   23.8        16.5    7.3
# 23   50.0        28.3   21.7
# 24   13.1        18.0    4.9
# 25   18.8        20.5    1.7
# 26   23.0        24.9    1.9
# 27   12.7        13.9    1.2
# 28    8.8         7.5    1.3
# 29   19.5        18.8    0.7
# 30   35.4        30.5    4.9
# 31   35.4        34.1    1.3
# 32   22.2        21.0    1.2
# 33   20.3        18.5    1.8
# 34   18.2        21.7    3.5
# 35   41.7        28.6   13.1
# 36   31.2        27.2    4.0
# 37   30.5        27.3    3.2
# 38   27.5        24.7    2.8
# 39   14.9        13.7    1.2
# 40   17.0        16.5    0.5
# 41   20.6        23.7    3.1
# 42   50.0        29.7   20.3
# 43   22.6        24.2    1.6
# 44   36.2        30.7    5.5
# 45    7.2        15.1    7.9
# 46   19.4        23.1    3.7
# 47   23.7        23.8    0.1
# 48   17.3        12.6    4.7
# 49   21.9        26.5    4.6
